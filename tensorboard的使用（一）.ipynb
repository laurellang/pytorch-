# %% [markdown]
# 学习：
# 1、SummaryWriter
# 2、add_scale（）函数
# 3、打开tensorboard： tensorboard --logdir=xxx --prot=6007

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter('logs')
# y = x
for i in range(100):
    writer.add_scalar("y = 2x", 3 * i, i)
writer.close()
